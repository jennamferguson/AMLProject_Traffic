# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('traffic_weather.csv')

# %%
data.isnull().sum()
# Out:
# Road Name      0
# Month          0
# Day            0
# Year           0
# Hour           0
# Day of Week    0
# Holiday        0
# Direction      0
# Speed          0
# Volume         0
# Full Date      0
# date           0
# tavg           0
# tmin           0
# tmax           0
# prcp           0
# snow           0
# wspd           0
# dtype: int64

# %%
# correlation matrix
numeric_data = data.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
correlation_matrix
# Out:
#                 Month       Day      Year      Hour  Day of Week   Holiday  \
# Month        1.000000 -0.011018 -0.264536  0.000402     0.012812  0.024583
# Day         -0.011018  1.000000 -0.010541  0.000742    -0.013006  0.016719
# Year        -0.264536 -0.010541  1.000000 -0.004014    -0.014892  0.001926
# Hour         0.000402  0.000742 -0.004014  1.000000     0.001646  0.000088
# Day of Week  0.012812 -0.013006 -0.014892  0.001646     1.000000 -0.090572
# Holiday      0.024583  0.016719  0.001926  0.000088    -0.090572  1.000000
# Speed        0.003506 -0.005461  0.082601 -0.257417    -0.032326  0.015348
# Volume      -0.009866 -0.002276 -0.199156  0.347785     0.051618 -0.038663
# tavg         0.160802  0.023386  0.094285 -0.000607     0.004984 -0.096950
# tmin         0.152039  0.018415  0.085090 -0.000966     0.012138 -0.094446
# tmax         0.168323  0.026306  0.102322  0.000336    -0.008878 -0.095353
# prcp         0.040589  0.005912 -0.020997 -0.007786     0.037615  0.008744
# snow        -0.041451 -0.003092  0.040589 -0.003832    -0.010074 -0.004952
# wspd        -0.210442  0.090512 -0.001307  0.000173     0.018935  0.013037
#
#                 Speed    Volume      tavg      tmin      tmax      prcp  \
# Month        0.003506 -0.009866  0.160802  0.152039  0.168323  0.040589
# Day         -0.005461 -0.002276  0.023386  0.018415  0.026306  0.005912
# Year         0.082601 -0.199156  0.094285  0.085090  0.102322 -0.020997
# Hour        -0.257417  0.347785 -0.000607 -0.000966  0.000336 -0.007786
# Day of Week -0.032326  0.051618  0.004984  0.012138 -0.008878  0.037615
# Holiday      0.015348 -0.038663 -0.096950 -0.094446 -0.095353  0.008744
# Speed        1.000000 -0.246199  0.011213  0.010631  0.012863  0.000637
# Volume      -0.246199  1.000000 -0.023468 -0.022536 -0.024518 -0.023168
# tavg         0.011213 -0.023468  1.000000  0.964584  0.970953 -0.044223
# tmin         0.010631 -0.022536  0.964584  1.000000  0.891601  0.009453
# tmax         0.012863 -0.024518  0.970953  0.891601  1.000000 -0.097693
# prcp         0.000637 -0.023168 -0.044223  0.009453 -0.097693  1.000000
# snow         0.027580 -0.015835 -0.071081 -0.068489 -0.065898  0.003597
# wspd        -0.019673  0.041634  0.022143  0.073627 -0.036663  0.047411
#
#                  snow      wspd
# Month       -0.041451 -0.210442
# Day         -0.003092  0.090512
# Year         0.040589 -0.001307
# Hour        -0.003832  0.000173
# Day of Week -0.010074  0.018935
# Holiday     -0.004952  0.013037
# Speed        0.027580 -0.019673
# Volume      -0.015835  0.041634
# tavg        -0.071081  0.022143
# tmin        -0.068489  0.073627
# tmax        -0.065898 -0.036663
# prcp         0.003597  0.047411
# snow         1.000000  0.014538
# wspd         0.014538  1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
#scatter plot of tavg and volume
sns.scatterplot(x='Speed', y='Volume', data=data)
plt.show()

# %%
data.describe()
# Out:
#                Month            Day           Year           Hour  \
# count  207672.000000  207672.000000  207672.000000  207672.000000
# mean        6.738405      15.459985    2018.983907      11.507261
# std         3.198461       8.844289       1.270045       6.916427
# min         1.000000       1.000000    2017.000000       0.000000
# 25%         4.000000       8.000000    2018.000000       6.000000
# 50%         7.000000      15.000000    2019.000000      12.000000
# 75%         9.000000      23.000000    2020.000000      17.000000
# max        12.000000      31.000000    2021.000000      23.000000
#
#          Day of Week        Holiday          Speed         Volume  \
# count  207672.000000  207672.000000  207672.000000  207672.000000
# mean        2.973266       0.036153      43.020523    1601.686645
# std         2.020785       0.186672      16.496007    1622.891093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000      32.000000     348.000000
# 50%         3.000000       0.000000      36.000000    1110.000000
# 75%         5.000000       0.000000      50.000000    2274.000000
# max         6.000000       1.000000     149.000000   15505.000000
#
#                 tavg           tmin           tmax           prcp  \
# count  207672.000000  207672.000000  207672.000000  207672.000000
# mean       21.998814      16.624043      28.420121       2.625547
# std         7.779917       8.010591       8.360819       9.742712
# min        -9.200000     -13.200000      -3.800000       0.000000
# 25%        16.200000      10.000000      22.800000       0.000000
# 50%        23.600000      18.900000      30.000000       0.000000
# 75%        28.500000      23.900000      35.000000       0.000000
# max        34.000000      28.900000      43.300000     129.000000
#
#                 snow           wspd
# count  207672.000000  207672.000000
# mean        0.047864       7.576167
# std         1.871955       3.246914
# min         0.000000       0.400000
# 25%         0.000000       5.000000
# 50%         0.000000       7.600000
# 75%         0.000000       9.700000
# max       150.000000      22.700000

# %%
data.dtypes
# Out:
# Road Name       object
# Month            int64
# Day              int64
# Year             int64
# Hour             int64
# Day of Week      int64
# Holiday          int64
# Direction       object
# Speed          float64
# Volume         float64
# Full Date       object
# date            object
# tavg           float64
# tmin           float64
# tmax           float64
# prcp           float64
# snow             int64
# wspd           float64
# dtype: object
